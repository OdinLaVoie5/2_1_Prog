# %%
def solution(number):

    """
    rezult = 0
    if number >= 0:    
        for i in range(number):
            if i % 3 == 0 or i % 5 == 0:
                rezult += i
    return rezult
    """

    # return sum(x for x in range(number) if x % 3 == 0 or x % 5 == 0)
 
    a3 = (number-1)//3
    a5 = (number-1)//5
    a15 = (number-1)//15
    result = (a3*(a3+1)/2)*3 + (a5*(a5+1)/2)*5 - (a15*(a15+1)/2)*15
    return result


solution(11)
# Out:
# 33.0

# %%
import math
def reduce_fraction(fraction):
    numdel = math.gcd(fraction[0], fraction[1])
    return (fraction[0]//numdel, fraction[1]//numdel)
reduce_fraction((6,3))
# Out:
# (2, 1)

# %%
def gcd(a, b):
    return a if b == 0 else gcd(b, a % b)

def reduce_fraction(fraction):
    num, denom = fraction
    gcd_num_denom = gcd(num, denom)
    return (num // gcd_num_denom, denom // gcd_num_denom)

reduce_fraction((6, 3))
# Out:
# (2, 1)

# %%
def uni_total(s): return sum(map(ord, s))


print(uni_total("прывэт"))


#    total = 0
#    for letter in s:
#        total += ord(letter)
#
#    def uni_total(s): return sum([ord(l) for l in s])
# Out:
# 6539

# %%
def multiply(n):
    return n * 5 ** len(str(abs(n)))

multiply(-3333)
# Out:
# -2083125

# %%
def remove(s): return s.replace('!', '') + '!'

remove('s!!!   s!!')

'ggg'.translate
# Out:
# 's   s!'

# %%
import math
def circle_diameter(sides, side_length): 
    return side_length / math.tan(math.pi/sides)


circle_diameter(4, 1)
# Out:
# 1.0000000000000002

# %%
def format_money(amount):
    return f'${amount:.2f}'


format_money(0)
# Out:
# '$0.00'

# %%
"""
def digitize(n):
    str_revers = str(n)[::-1]
    rezult_list = [int(i) for i in str_revers]
    return rezult_list
"""


def digitize(n):
    return [int(x) for x in reversed(str(n))]

digitize(75328)
# Out:
# [8, 2, 3, 5, 7]

# %%
import math
n =[*'58999997961']
m = math.prod(map(int, n))
m
# Out:
# 892820880

# %%
num = input()
print(sum(int(x) for x in num))
# print((int(x) for x in num))
rezult = 1
for x in num:
     rezult *= int(x)
print(rezult)
# Out:
# 15
# [4, 5, 6]
# 120

# %%
str1 = input()
print(str1)
print(str1[0], str1[2],str1[1], sep='')
print(str1[1], str1[2], str1[0], sep='')
print(str1[1], str1[0], str1[2], sep='')
print(str1[2], str1[0], str1[1], sep='')
print(str1[2], str1[1], str1[0], sep='')
# Out:
# 123
# 132
# 231
# 213
# 312
# 321

# %%
def comby (s):
    
    return s[0] + s[-1]

comby('hello')
# Out:
# 'ho'

# %%
str1 ='hello'
arr1 = list(str1)
for i in range(len(arr1)):
     print(arr1)
     arr1 = arr1[1:] + arr1[:1]
# Out:
# ['h', 'e', 'l', 'l', 'o']
# ['e', 'l', 'l', 'o', 'h']
# ['l', 'l', 'o', 'h', 'e']
# ['l', 'o', 'h', 'e', 'l']
# ['o', 'h', 'e', 'l', 'l']

# %%
# недодел    рекурсия  перебор вариантов

str1 = 'hel'
def comby (s): 
    arr = list(s)
    for i in range(len(arr)):
        print(arr)
        arr = arr[1:] + arr[:1]
        print(arr[0], end='')
        comby(arr[1:])

comby(str1)
# Out:
# ['h', 'e', 'l']
# e['l', 'h']
# h['l']
# l['h', 'l']
# l['h']
# h['e', 'l', 'h']
# l['h', 'e']
# e['h']
# h['e', 'h']
# h['e']
# e['l', 'h', 'e']
# h['e', 'l']
# l['e']
# e['l', 'e']
# e['l']
# l

# %%
# put your python code here
s = input()
print(f'Цифра в позиции тысяч равна {s[0]}')
print(f'Цифра в позиции сотен равна {s[1]}')
print(f'Цифра в позиции десятков равна {s[2]}')
print(f'Цифра в позиции единиц равна {s[3]}')
# Out:
# Цифра в позиции тысяч равна 1
# Цифра в позиции сотен равна 2
# Цифра в позиции десятков равна 3
# Цифра в позиции единиц равна 4

# %%
print("The world's a little blurry", "Or maybe it's my eyes", end='!!!', sep=' :) ')
# Out:
# The world's a little blurry :) Or maybe it's my eyes!!!

# %%
print(*range(6))
# Out:
# 0 1 2 3 4 5
